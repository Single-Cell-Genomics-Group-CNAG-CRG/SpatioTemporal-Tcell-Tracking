# %% [markdown]
# # 4.0-Level 1 annotation
#
# **Inés Sentís**

# %% [markdown]
# Date of execution

# %%
Sys.Date()
# Out:
# [1] "2025-01-10"

# %% [markdown]
# ## Introduction

# %% [markdown]
# Level 1 annotation of main cell types

# %%
timepoint <- "T7"

# %% [markdown]
# ## Libraries

# %%
suppressMessages(suppressWarnings({
library(Seurat)
library(here)
library(glue)
library(tidyverse)
library(ggplot2)
library(dplyr)
}))

# %% [markdown]
# ## Parameters

# %%
#dr_here(show_reason = TRUE)
source(here("SCGRES_119_120/sc_analysis/misc/paths.R"))
source(here("utils/bin.R"))

"{annot}/{plt_dir}" %>%
  glue::glue() %>%
  here::here() %>%
  dir.create(path = .,
           showWarnings = FALSE,
           recursive = TRUE)

"{annot}/{robj_dir}" %>%
  glue::glue() %>%
  here::here() %>%
  dir.create(path = .,
           showWarnings = FALSE,
           recursive = TRUE)

set.seed(0)

# %% [markdown]
# ## Load data

# %%
# read object
seurat_obj <- readRDS(here(glue("{clust}/{robj_dir}/3.2-clustering_{timepoint}.rds")))

# markers
rna.markers <- read_csv(here(glue("{clust}/{robj_dir}/3.2-clustering_{timepoint}.csv")))
# Out:
# Rows: 18845 Columns: 7
# ── Column specification ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): gene
# dbl (6): p_val, avg_log2FC, pct.1, pct.2, p_val_adj, cluster
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
options(repr.plot.width = 6, repr.plot.height = 6, warn=-1,verbose = FALSE)
DimPlot(
  seurat_obj,
  reduction = "umap",
  pt.size = 0.1,
  label=T,
) + ggtitle(glue('UMAP {timepoint}')) + 
    theme(plot.title = element_text(hjust = 0.5, size = 12, face = "bold"))
# Out:
# plot without title

# %%
options(repr.plot.width = 6, repr.plot.height = 6, warn=-1,verbose = FALSE)
DimPlot(
  seurat_obj,
  reduction = "umap",
  group.by = "sample_id",
  pt.size = 0.1,
) + ggtitle(glue('UMAP {timepoint}')) + 
    theme(plot.title = element_text(hjust = 0.5, size = 12, face = "bold"))
# Out:
# plot without title

# %% [markdown]
# ### Check general cell types
#
# Plot specific markers to annotate main cell types

# %% [markdown]
# #### T-cells

# %%
markers = c("CD3E", "CD3G","CD4","CD8A", "CD8B","ANXA1","GZMK","FOXP3")

# %%
options(repr.plot.width = 18, repr.plot.height = 10, warn=-1,verbose = FALSE)
VlnPlot(seurat_obj,features=markers,ncol=4, pt.size = 0)
# Out:
# plot without title

# %% [markdown]
# #### Natural Killers

# %%
markers = c("NCAM1", "FCGR3A", "CX3CR1", "GNLY", "KLRC2", "KLRD1", "KLRC3", "KLRK1", "KLRC1", "GNLY", "NKG7")

# %%
options(repr.plot.width = 18, repr.plot.height = 15, warn=-1,verbose = FALSE)
VlnPlot(seurat_obj,features=markers,ncol=4, pt.size = 0)
# Out:
# plot without title

# %% [markdown]
# #### B-cells

# %%
markers = c("CD19","MS4A1","CCR7", "SELL","ITGAX", "CD79A","CD79B","JCHAIN","IGHA1")

# %%
options(repr.plot.width = 18, repr.plot.height = 15, warn=-1,verbose = FALSE)
VlnPlot(seurat_obj,features=markers,ncol=4, pt.size = 0)
# Out:
# plot without title

# %% [markdown]
# #### Monocytes

# %%
markers = c("CD68","CD14", "S100A8", "S100A9", "LYZ", "VCAN", 
            "FCN1","FCGR3A", "CX3CR1", "HLA-DRB1", "HLA-DRA")

# %%
options(repr.plot.width = 18, repr.plot.height = 15, warn=-1,verbose = FALSE)
VlnPlot(seurat_obj,features=markers,ncol=4, pt.size = 0)
# Out:
# plot without title

# %% [markdown]
# #### Dendritic cells

# %%
markers = c("CLEC9A", "XCR1", "IDO1","FCER1A", "FCER1A",
            "CLEC10A","ITGAX","SIGLEC6","IL3RA","CD1C")

# %%
options(repr.plot.width = 18, repr.plot.height = 15, warn=-1,verbose = FALSE)
VlnPlot(seurat_obj,features=markers,ncol=4, pt.size = 0)
# Out:
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 5, warn=-1,verbose = FALSE)
FeaturePlot(seurat_obj, reduction = "umap", 
            features=c("CD34", "KIT"), 
            order = TRUE, ncol=2)
# Out:
# plot without title

# %% [markdown]
# ## Renaming

# %%
rename_clusters= list("0"="Monocytes",
                      "1"="B-cells",
                      "2"="CD4 T-cells",
                      "3"="CD4 T-cells",
                      "4"="CD8 T-cells",
                      "5"="CD4 T-cells",
                      "6"="Macrophages",
                      "7"="NK",
                      "8"="CD8 T-cells",
                      "9"="CD4 T-cells",
                      "10"="Plasma cells",
                      "11"="Plasma cells",
                      "12"="Platelets")
    
seurat_obj <- RenameIdents(object = seurat_obj, rename_clusters)
seurat_obj$l1_annot <- Idents(seurat_obj)

# %%
options(repr.plot.width = 6, repr.plot.height = 6, warn=-1,verbose = FALSE)
DimPlot(
  seurat_obj,
  reduction = "umap",
  pt.size = 0.1,
  label = T
) + NoLegend() + ggtitle(glue('UMAP {timepoint}')) + 
    theme(plot.title = element_text(hjust = 0.5, size = 12, face = "bold"))
# Out:
# plot without title

# %% [markdown]
# ## Save

# %%
saveRDS(seurat_obj, here::here(glue::glue("{annot}/{robj_dir}/4.0-l1_all_{timepoint}.rds")))

# %% [markdown]
# ## SessionInfo

# %%
sessionInfo()
# Out:
# R version 4.1.1 (2021-08-10)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: CentOS Linux 7 (Core)
#
# Matrix products: default
# BLAS/LAPACK: /home/groups/singlecell/isentis/conda_envs/ines_r4.1.1c/lib/libopenblasp-r0.3.24.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=es_ES.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=es_ES.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=es_ES.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=es_ES.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] lubridate_1.9.3    forcats_1.0.0      stringr_1.5.0      dplyr_1.1.3
#  [5] purrr_1.0.2        readr_2.1.4        tidyr_1.3.0        tibble_3.2.1
#  [9] ggplot2_3.4.4      tidyverse_2.0.0    glue_1.6.2         here_1.0.1
# [13] SeuratObject_4.1.4 Seurat_4.0.5
#
# loaded via a namespace (and not attached):
#   [1] Rtsne_0.16            colorspace_2.1-0      deldir_1.0-9
#   [4] ellipsis_0.3.2        ggridges_0.5.4        rprojroot_2.0.3
#   [7] IRdisplay_1.1         base64enc_0.1-3       spatstat.data_3.0-1
#  [10] farver_2.1.1          leiden_0.4.3          listenv_0.9.0
#  [13] bit64_4.0.5           ggrepel_0.9.4         fansi_1.0.5
#  [16] codetools_0.2-19      splines_4.1.1         polyclip_1.10-4
#  [19] IRkernel_1.3.2.9000   jsonlite_1.8.7        Cairo_1.6-2
#  [22] ica_1.0-3             cluster_2.1.4         png_0.1-8
#  [25] uwot_0.1.16           shiny_1.7.5.1         sctransform_0.4.0
#  [28] spatstat.sparse_3.0-1 compiler_4.1.1        httr_1.4.7
#  [31] Matrix_1.6-1.1        fastmap_1.1.1         lazyeval_0.2.2
#  [34] cli_3.6.1             later_1.3.1           htmltools_0.5.6.1
#  [37] tools_4.1.1           igraph_1.3.4          gtable_0.3.4
#  [40] RANN_2.6.1            reshape2_1.4.4        Rcpp_1.0.10
#  [43] scattermore_1.2       vctrs_0.6.4           nlme_3.1-162
#  [46] progressr_0.14.0      lmtest_0.9-40         spatstat.random_3.1-5
#  [49] globals_0.16.2        timechange_0.2.0      mime_0.12
#  [52] miniUI_0.1.1.1        lifecycle_1.0.3       irlba_2.3.5.1
#  [55] goftest_1.2-3         future_1.33.0         MASS_7.3-60
#  [58] zoo_1.8-12            scales_1.2.1          vroom_1.6.4
#  [61] spatstat.core_2.4-2   hms_1.1.3             promises_1.2.1
#  [64] spatstat.utils_3.0-3  parallel_4.1.1        RColorBrewer_1.1-3
#  [67] reticulate_1.34.0     pbapply_1.7-2         gridExtra_2.3
#  [70] rpart_4.1.19          stringi_1.7.12        repr_1.1.6
#  [73] rlang_1.1.1           pkgconfig_2.0.3       matrixStats_1.0.0
#  [76] evaluate_0.22         lattice_0.21-8        ROCR_1.0-11
#  [79] tensor_1.5            labeling_0.4.3        patchwork_1.1.3
#  [82] htmlwidgets_1.6.2     bit_4.0.5             cowplot_1.1.1
#  [85] tidyselect_1.2.0      parallelly_1.36.0     RcppAnnoy_0.0.21
#  [88] plyr_1.8.9            magrittr_2.0.3        R6_2.5.1
#  [91] generics_0.1.3        pbdZMQ_0.3-10         withr_2.5.1
#  [94] pillar_1.9.0          mgcv_1.8-42           fitdistrplus_1.1-11
#  [97] survival_3.5-7        abind_1.4-5           sp_2.1-0
# [100] future.apply_1.11.0   crayon_1.5.2          uuid_1.1-1
# [103] KernSmooth_2.23-22    utf8_1.2.3            spatstat.geom_3.2-5
# [106] plotly_4.10.2         tzdb_0.4.0            grid_4.1.1
# [109] data.table_1.14.8     digest_0.6.33         xtable_1.8-4
# [112] httpuv_1.6.11         munsell_0.5.0         viridisLite_0.4.2
